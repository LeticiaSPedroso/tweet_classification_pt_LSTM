# %% [markdown]
# Importes para as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping

# %% [markdown]
# Leitura do arquivo

# %%
df = pd.read_csv('Train3Classes.csv',delimiter=';',encoding='latin-1')

# %%
df
# Out:
#                         id                                         tweet_text  \
# 0      1050785521201541121  @Laranjito76 A pessoa certa para isso seria o ...
# 1      1050785431955140608  @behin_d_curtain Para mim, Ã© precisamente o c...
# 2      1050785401248645120  Vou fazer um video hoje... estou pensando em f...
# 3      1050785370982547461  aaaaaaaa amei tanto essas polaroids, nem sei e...
# 4      1050785368902131713  Valoriza o coraÃ§Ã£o do menininho que vc tem. ...
# 5      1050785368008781825       @KingJokerLeto mas amiga eu to aqui ainda :)
# 6      1050785350724014080                   @RivasJairo Bravo, Jairo!!! :)))
# 7      1050785336551444480  @inquilinasls @Spotify socorro ksoaksosks acho...
# 8      1050785297028603905  @chimekarlla gosto muito de fazenda :) , mas m...
# 9      1050785215235256320                            Amanha vou ver venom :D
# 10     1050785194108735490  Porque simplesmente as coisas que me deixam ch...
# 11     1050785191529250816  A partir de segunda comeÃ§a uma nova rotina, e...
# 12     1050785175578251266  Meu amigo parece estar apaixonado por vc â Ã...
# 13     1050785147052847104  @Goncla_Silva Ã©s um gajo bacano, vÃª lÃ¡ se n...
# 14     1050785125770948608            tou a ver videos de cabrinhas bebÃ©s :D
# 15     1050785090484269056  @Danniel_Sampa Vou verificar jÃ¡ o que estÃ¡ o...
# 16     1050785084540952576                 @gabriolaz Quando for me chama? :)
# 17     1050785048834793474  @bronza Se fosse sÃ³ nariz... Ã olho, Ã© ouvi...
# 18     1050785028316250114  @SandwormPT O primeiro capÃ­tulo jÃ¡ estÃ¡ esc...
# 19     1050785006522642433               feliz dia :p https://t.co/uCgjbaGmfi
# 20     1050784978248839171           @anadantassa_ Feliz dia das crianÃ§as :)
# 21     1050784928651255809                  @tassiddm jÃ¡ tÃ´ calminha jÃ¡ :)
# 22     1050784847701176321  @_pat3icia_ @FOX_PT Sem problema. Eu como vi m...
# 23     1050784833536962561   sou muito fotogÃªnico :D https://t.co/0lSwaZGQvj
# 24     1050784832308084736  @RaiamMaia passei no concurso pra monlevade, s...
# 25     1050784787852607494             Sexta linda :) https://t.co/wWKZZMKvaj
# 26     1050784712602636288  Feliz dia das crianÃ§as :) Eu e Lula, amigos d...
# 27     1050784680230948864  @LucioMarinell Google it :). NÃ£o sofra com re...
# 28     1050784671557197825  Quero agradecer aos novos seguidores. Eu ainda...
# 29     1050784658366111749                           JÃ¡ estou na #BGS2018 :)
# ...                    ...                                                ...
# 99970  1030475607422001152  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99971  1030475471757209601  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99972  1030474998484529152  Vaga para Consultor de InteligÃªncia de NegÃ³c...
# 99973  1030474883145363457  Veja o que Ã© #FATO ou #FAKE nas falas dos can...
# 99974  1030474763863511040  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99975  1030474759199444993  Coluna InovaÃ§Ã£o | O paradoxo entre emprego e...
# 99976  1030474631847788547  Veja o que Ã© #FATO ou #FAKE nas falas dos can...
# 99977  1030474541687025664  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99978  1030474331317522435  Veja o que Ã© #FATO ou #FAKE nas falas dos can...
# 99979  1030474330549829633  Veja o que Ã© #FATO ou #FAKE nas falas dos can...
# 99980  1030474139218452486  Vaga para LÃ­der do Controle de Qualidade, em ...
# 99981  1030473769058545664  Motorista Carreteiro - JundiaÃ­, SP https://t....
# 99982  1030473751438217216  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99983  1030473533053444097  ParabÃ©ns @Dedevital vocÃª merece demais! Ã o...
# 99984  1030473280824770560  Vaga para Auditor Externo (Contabilidade), em ...
# 99985  1030473027425906689  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...
# 99986  1030472367993184256  Vagas para Analistas de InteligÃªncia de Merca...
# 99987  1030471385699823616  FaÃ§a sua reserva pelo WhatsApp: https://t.co/...
# 99988  1030470928466161664  Vata para Analista de Qualidade, em Porto Aleg...
# 99989  1030470150347268096  Vaga para Analista Programador, e Engenheiro E...
# 99990  1030469574700003329  Vaga para Comprador Pleno, em Caxias do Sul/RS...
# 99991  1030469254410379264  Vaga para Assessor Comercial, em Curitiba/PR. ...
# 99992  1030469137242497025  Verdade. @FilosofeiLucas #fato https://t.co/eC...
# 99993  1030468748464062466  ParabÃ©ns, Abeoc SÃ£o Paulo. #trabalho #evento...
# 99994  1030468574085705728  De volta ao trabalho...a vida Ã© feita de degr...
# 99995  1030468564715794432  Confira esta vaga na Senac-RS: Editor De Video...
# 99996  1030468147353210881  Confira esta vaga na Grupo SABEMI: Assistente ...
# 99997  1030467484766359552  Confira esta vaga na Groupe LâOCCITANE: Gere...
# 99998  1030466921702076416  EstÃ¡ no ar o CandidatoWEB, seu novo portal de...
# 99999  1027373651585249280  AnavitÃ³ria industrializa pop folk em Ã¡lbum p...
#
#                            tweet_date  sentiment     query_used
# 0      Fri Oct 12 16:29:25 +0000 2018          1             :)
# 1      Fri Oct 12 16:29:04 +0000 2018          1             :)
# 2      Fri Oct 12 16:28:56 +0000 2018          1             :)
# 3      Fri Oct 12 16:28:49 +0000 2018          1             :)
# 4      Fri Oct 12 16:28:49 +0000 2018          1             :)
# 5      Fri Oct 12 16:28:49 +0000 2018          1             :)
# 6      Fri Oct 12 16:28:44 +0000 2018          1             :)
# 7      Fri Oct 12 16:28:41 +0000 2018          1             :)
# 8      Fri Oct 12 16:28:32 +0000 2018          1             :)
# 9      Fri Oct 12 16:28:12 +0000 2018          1             :)
# 10     Fri Oct 12 16:28:07 +0000 2018          1             :)
# 11     Fri Oct 12 16:28:06 +0000 2018          1             :)
# 12     Fri Oct 12 16:28:03 +0000 2018          1             :)
# 13     Fri Oct 12 16:27:56 +0000 2018          1             :)
# 14     Fri Oct 12 16:27:51 +0000 2018          1             :)
# 15     Fri Oct 12 16:27:42 +0000 2018          1             :)
# 16     Fri Oct 12 16:27:41 +0000 2018          1             :)
# 17     Fri Oct 12 16:27:32 +0000 2018          1             :)
# 18     Fri Oct 12 16:27:28 +0000 2018          1             :)
# 19     Fri Oct 12 16:27:22 +0000 2018          1             :)
# 20     Fri Oct 12 16:27:16 +0000 2018          1             :)
# 21     Fri Oct 12 16:27:04 +0000 2018          1             :)
# 22     Fri Oct 12 16:26:44 +0000 2018          1             :)
# 23     Fri Oct 12 16:26:41 +0000 2018          1             :)
# 24     Fri Oct 12 16:26:41 +0000 2018          1             :)
# 25     Fri Oct 12 16:26:30 +0000 2018          1             :)
# 26     Fri Oct 12 16:26:12 +0000 2018          1             :)
# 27     Fri Oct 12 16:26:05 +0000 2018          1             :)
# 28     Fri Oct 12 16:26:02 +0000 2018          1             :)
# 29     Fri Oct 12 16:25:59 +0000 2018          1             :)
# ...                               ...        ...            ...
# 99970  Fri Aug 17 15:25:04 +0000 2018          2       #noticia
# 99971  Fri Aug 17 15:24:32 +0000 2018          2       #noticia
# 99972  Fri Aug 17 15:22:39 +0000 2018          2  #oportunidade
# 99973  Fri Aug 17 15:22:12 +0000 2018          2          #fato
# 99974  Fri Aug 17 15:21:43 +0000 2018          2       #noticia
# 99975  Fri Aug 17 15:21:42 +0000 2018          2      #trabalho
# 99976  Fri Aug 17 15:21:12 +0000 2018          2          #fato
# 99977  Fri Aug 17 15:20:50 +0000 2018          2       #noticia
# 99978  Fri Aug 17 15:20:00 +0000 2018          2          #fato
# 99979  Fri Aug 17 15:20:00 +0000 2018          2          #fato
# 99980  Fri Aug 17 15:19:14 +0000 2018          2  #oportunidade
# 99981  Fri Aug 17 15:17:46 +0000 2018          2  #oportunidade
# 99982  Fri Aug 17 15:17:42 +0000 2018          2       #noticia
# 99983  Fri Aug 17 15:16:50 +0000 2018          2          #fato
# 99984  Fri Aug 17 15:15:50 +0000 2018          2  #oportunidade
# 99985  Fri Aug 17 15:14:49 +0000 2018          2       #noticia
# 99986  Fri Aug 17 15:12:12 +0000 2018          2  #oportunidade
# 99987  Fri Aug 17 15:08:18 +0000 2018          2      #novidade
# 99988  Fri Aug 17 15:06:29 +0000 2018          2  #oportunidade
# 99989  Fri Aug 17 15:03:23 +0000 2018          2  #oportunidade
# 99990  Fri Aug 17 15:01:06 +0000 2018          2  #oportunidade
# 99991  Fri Aug 17 14:59:50 +0000 2018          2  #oportunidade
# 99992  Fri Aug 17 14:59:22 +0000 2018          2          #fato
# 99993  Fri Aug 17 14:57:49 +0000 2018          2      #trabalho
# 99994  Fri Aug 17 14:57:07 +0000 2018          2      #trabalho
# 99995  Fri Aug 17 14:57:05 +0000 2018          2  #oportunidade
# 99996  Fri Aug 17 14:55:26 +0000 2018          2  #oportunidade
# 99997  Fri Aug 17 14:52:48 +0000 2018          2  #oportunidade
# 99998  Fri Aug 17 14:50:33 +0000 2018          2      #trabalho
# 99999  Thu Aug 09 01:59:00 +0000 2018          2             g1
#
# [100000 rows x 5 columns]

# %% [markdown]
# Pré-processamento

# %%
df.dropna()

df = df.drop(columns=["tweet_date","id","query_used"])

# %%
df
# Out:
#                                               tweet_text  sentiment
# 0      @Laranjito76 A pessoa certa para isso seria o ...          1
# 1      @behin_d_curtain Para mim, Ã© precisamente o c...          1
# 2      Vou fazer um video hoje... estou pensando em f...          1
# 3      aaaaaaaa amei tanto essas polaroids, nem sei e...          1
# 4      Valoriza o coraÃ§Ã£o do menininho que vc tem. ...          1
# 5           @KingJokerLeto mas amiga eu to aqui ainda :)          1
# 6                       @RivasJairo Bravo, Jairo!!! :)))          1
# 7      @inquilinasls @Spotify socorro ksoaksosks acho...          1
# 8      @chimekarlla gosto muito de fazenda :) , mas m...          1
# 9                                Amanha vou ver venom :D          1
# 10     Porque simplesmente as coisas que me deixam ch...          1
# 11     A partir de segunda comeÃ§a uma nova rotina, e...          1
# 12     Meu amigo parece estar apaixonado por vc â Ã...          1
# 13     @Goncla_Silva Ã©s um gajo bacano, vÃª lÃ¡ se n...          1
# 14               tou a ver videos de cabrinhas bebÃ©s :D          1
# 15     @Danniel_Sampa Vou verificar jÃ¡ o que estÃ¡ o...          1
# 16                    @gabriolaz Quando for me chama? :)          1
# 17     @bronza Se fosse sÃ³ nariz... Ã olho, Ã© ouvi...          1
# 18     @SandwormPT O primeiro capÃ­tulo jÃ¡ estÃ¡ esc...          1
# 19                  feliz dia :p https://t.co/uCgjbaGmfi          1
# 20              @anadantassa_ Feliz dia das crianÃ§as :)          1
# 21                     @tassiddm jÃ¡ tÃ´ calminha jÃ¡ :)          1
# 22     @_pat3icia_ @FOX_PT Sem problema. Eu como vi m...          1
# 23      sou muito fotogÃªnico :D https://t.co/0lSwaZGQvj          1
# 24     @RaiamMaia passei no concurso pra monlevade, s...          1
# 25                Sexta linda :) https://t.co/wWKZZMKvaj          1
# 26     Feliz dia das crianÃ§as :) Eu e Lula, amigos d...          1
# 27     @LucioMarinell Google it :). NÃ£o sofra com re...          1
# 28     Quero agradecer aos novos seguidores. Eu ainda...          1
# 29                              JÃ¡ estou na #BGS2018 :)          1
# ...                                                  ...        ...
# 99970  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99971  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99972  Vaga para Consultor de InteligÃªncia de NegÃ³c...          2
# 99973  Veja o que Ã© #FATO ou #FAKE nas falas dos can...          2
# 99974  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99975  Coluna InovaÃ§Ã£o | O paradoxo entre emprego e...          2
# 99976  Veja o que Ã© #FATO ou #FAKE nas falas dos can...          2
# 99977  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99978  Veja o que Ã© #FATO ou #FAKE nas falas dos can...          2
# 99979  Veja o que Ã© #FATO ou #FAKE nas falas dos can...          2
# 99980  Vaga para LÃ­der do Controle de Qualidade, em ...          2
# 99981  Motorista Carreteiro - JundiaÃ­, SP https://t....          2
# 99982  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99983  ParabÃ©ns @Dedevital vocÃª merece demais! Ã o...          2
# 99984  Vaga para Auditor Externo (Contabilidade), em ...          2
# 99985  ð±DESCUBRA Quando 4 temporada da sÃ©rie GOTH...          2
# 99986  Vagas para Analistas de InteligÃªncia de Merca...          2
# 99987  FaÃ§a sua reserva pelo WhatsApp: https://t.co/...          2
# 99988  Vata para Analista de Qualidade, em Porto Aleg...          2
# 99989  Vaga para Analista Programador, e Engenheiro E...          2
# 99990  Vaga para Comprador Pleno, em Caxias do Sul/RS...          2
# 99991  Vaga para Assessor Comercial, em Curitiba/PR. ...          2
# 99992  Verdade. @FilosofeiLucas #fato https://t.co/eC...          2
# 99993  ParabÃ©ns, Abeoc SÃ£o Paulo. #trabalho #evento...          2
# 99994  De volta ao trabalho...a vida Ã© feita de degr...          2
# 99995  Confira esta vaga na Senac-RS: Editor De Video...          2
# 99996  Confira esta vaga na Grupo SABEMI: Assistente ...          2
# 99997  Confira esta vaga na Groupe LâOCCITANE: Gere...          2
# 99998  EstÃ¡ no ar o CandidatoWEB, seu novo portal de...          2
# 99999  AnavitÃ³ria industrializa pop folk em Ã¡lbum p...          2
#
# [100000 rows x 2 columns]

# %% [markdown]
# Separação dos dados para treino e teste, e transformação desses dados

# %%
X = df.tweet_text
Y = df.sentiment
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# Tokenização das palavras

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %% [markdown]
# Construção da rede neural

# %%
def RNN():
    
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(32)(layer)
    layer = Dense(512,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %% [markdown]
# Treinamento

# %%
model = RNN()
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\lsilvape\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\lsilvape\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 150)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 150, 50)           50000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                10624
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16896
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 513
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 78,033
# Trainable params: 78,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sequences_matrix,Y_train,batch_size=32,epochs=10,
          validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# WARNING:tensorflow:From C:\Users\lsilvape\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 76500 samples, validate on 8500 samples
# Epoch 1/10
# 76500/76500 [==============================] - 244s 3ms/step - loss: -4.6001 - acc: 0.4719 - val_loss: -4.6741 - val_acc: 0.5062
# Epoch 2/10
# 76500/76500 [==============================] - 267s 3ms/step - loss: -4.7941 - acc: 0.5029 - val_loss: -4.5780 - val_acc: 0.5134

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

accr = model.evaluate(test_sequences_matrix,Y_test)

print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 15000/15000 [==============================] - 9s 602us/step
# Test set
#   Loss: -4.581
#   Accuracy: 0.506
